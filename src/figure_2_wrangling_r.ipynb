# %%
library(ggplot2)
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.2.1 ──
# ✔ tibble  2.1.3     ✔ purrr   0.3.3
# ✔ tidyr   1.0.0     ✔ dplyr   0.8.3
# ✔ readr   1.3.1     ✔ stringr 1.4.0
# ✔ tibble  2.1.3     ✔ forcats 0.4.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
data <- read.csv('../data/wrangling_for_r_figure_2.csv')

# %%
options(repr.plot.height = 3, repr.plot.width = 6)
data <- read.csv('../data/wrangling_for_r_figure_2.csv')
data %>% ggplot(aes(year, total, color = job_gender_dominant_group)) + 
    geom_line() +
    labs(title = "Number of Job Gender Dominant Groups by Year", 
         x = "Year", y = 'Number of Jobs', color = 'Job Gender Dominant Group')
# Out:
# plot without title
